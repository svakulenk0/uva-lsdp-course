# %% [markdown]
# # RNN Classification Test
# Trying to classify the age of an author based on a written blogpost
#
# ## 1. Import libraries

# %%
# !pip install torchtext==0.4
# Out:
# Requirement already satisfied: torchtext==0.4 in /usr/local/lib/python3.7/dist-packages (0.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4) (2.23.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4) (1.8.0+cu101)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4) (1.19.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4) (2020.12.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchtext==0.4) (3.7.4.3)

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import re
import os
import time

import torch
import torchtext
from torchtext.datasets import text_classification
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.data.dataset import random_split
import nltk
import plotly.express as px
from nltk.stem import WordNetLemmatizer
import plotly.graph_objs as go
nltk.download('wordnet')
nltk.download('stopwords')

from collections import defaultdict, OrderedDict, Counter
import operator
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## 2. Load and preprocces the dataframe

# %%
path = '/content/drive/MyDrive/Language, speech and dialogue processing/blogtext_full.xlsx'

# %%
dataset = pd.read_excel(path)
df = pd.DataFrame(dataset)
df = df.drop(['id', 'topic', 'sign', 'date', 'gender'], axis=1)

df = df.sample(300000)
ages = df["age"].unique().tolist()
print(ages)
# Out:
# [24, 25, 15, 16, 34, 23, 33, 17, 26, 14, 27, 13, 39, 40, 41, 47, 42, 37, 35, 44, 38, 46, 36, 48, 43, 45]

# %%
ages.sort()
age_dict = {}
for age in ages:
  age_dict[age] = df.loc[df['age'] == age]

for key, value in age_dict.items():
  age_dict[key] = value
  
print(age_dict)
# Out:
# {13:         age                                               text
# 5753     13           hello! Good Evening! Just had my dinn...
# 168188   13                   Ok. That be all engrish happy...
# 260580   13             The kind folks at JobStarts put on ...
# 191153   13         i will comment on your blog if you comm...
# 118362   13         Mood: Pissed Off Music: Disco Duck? Wtf...
# ...     ...                                                ...
# 127829   13  Hey There* Well It has been just a DELIGHTFUL ...
# 172821   13              Cherry I Love U   urlLink
# 232380   13         Three Days Grace - [I Hate] Everything ...
# 117159   13               urlLink    haru&nbsp; urlLink
# 126812   13  YesTerDay(22/07/2004).. Is One my most happies...
#
# [5756 rows x 2 columns], 14:         age                                               text
# 351431   14          Deanna's journal says that they still ...
# 558972   14             Im in your comic..yahhoo!!!!  nikki...
# 165431   14     I just made this thing. It was in Dylan's p...
# 7394     14          hey ppl..today had the speech thingy.....
# 217651   14              Randome Shite! lol.       Emily St...
# ...     ...                                                ...
# 297534   14  hey hey peeps.. sorry for not updatin my blog ...
# 18990    14         In the time of chimpanzees I was a monk...
# 304196   14                   Ok I'm looking for a new titl...
# 86728    14  arlow!hmmm..todae was pretty exciting..early m...
# 452729   14             Well, it's taken me long enough to ...
#
# [12123 rows x 2 columns], 15:         age                                               text
# 113595   15          Time for an actual entry and not just ...
# 166157   15  PrinceIceCube: I just am afraid of loosing you...
# 278248   15               Debate, eh? Bring it...   You rea...
# 256586   15             Tonight, comes the Tiger...  Click ...
# 339111   15                   wow. no life right here.  ama...
# ...     ...                                                ...
# 267683   15  Yusuke! You are basek off of Fire signs! GO YO...
# 414339   15                        All emo kids look like H...
# 385766   15         geez sometimes i think i have really su...
# 75547    15         there is a reason why my nickname was m...
# 284654   15  Well...today Sherah is here!  woohoo!    And I...
#
# [18415 rows x 2 columns], 16:         age                                               text
# 152379   16               ok so I think the story is kinda ...
# 82948    16  KOMO July 16, 2004    'Bush on Mars in 2004' b...
# 372745   16                 merry christmas everyone.
# 317498   16         A lot of people have been asking me thi...
# 556969   16         AH HAHAHA FUCK SCHOOL! I haven't woken ...
# ...     ...                                                ...
# 486696   16         Sometimes I feel like this thing causes...
# 234354   16  Pheew at last abes gak test..tdi DE ppr punye ...
# 526649   16                                         Bonus.
# 562984   16         No school today!  A foot of snow!   Woo...
# 395271   16  Quartet rehearsal was decent, we stood up and ...
#
# [31991 rows x 2 columns], 17:         age                                               text
# 291122   17      urlLink    The plaque commemorating 'Thoma...
# 365976   17  nahahaha.  just came back from  Jurong East Sw...
# 468318   17  Great, now I'm talking to my blog. *sigh* I'm ...
# 445510   17               ARGH. Why the hell do people do t...
# 596211   17                    Current Song: Def Leppard- P...
# ...     ...                                                ...
# 168161   17                        how disheartening.
# 91820    17  Damn...I fell old.  I played badminton for 3 h...
# 135846   17  blah was last night a dream did derek and loga...
# 533715   17         MMM...I'm bored...I'm chatting with som...
# 320369   17               AH I got it from Paul, thanks.   ...
#
# [35853 rows x 2 columns], 23:         age                                               text
# 9879     23          Baby in Yellow Lotus  urlLink
# 282767   23  Tonight I was really bored. I had nothing to d...
# 69717    23             That was taken completely out of co...
# 604055   23                   Just wanted to post some pics...
# 156664   23         You know you see people walking around ...
# ...     ...                                                ...
# 451170   23               hello weekend! it's saturday and ...
# 302756   23                    urlLink    The Penguins at t...
# 354365   23               i would definitely be excited for...
# 40246    23  urlLink     Get a load of this  urlLink articl...
# 472289   23               Whoah...last night was cool, got ...
#
# [32054 rows x 2 columns], 24:         age                                               text
# 630407   24  its amazing how much maintenance one can get d...
# 674287   24                           urlLink 288th !  Woohoo!
# 81468    24         This Blog things gonna take some gettin...
# 279611   24  ...and the ThunderBats are in 8th, 20.5 games ...
# 621588   24                   Red Rollover Gone! :) I feel ...
# ...     ...                                                ...
# 605383   24                :(  My last Fishlet (tm) died a ...
# 388130   24             I saw  Napoleon Dynamite  for the s...
# 177179   24  Went to visit grandparents aft paying respects...
# 408262   24  THANK YOU   This post is dedicated to the men ...
# 316945   24  urlLink test  An old game, my record... is... ...
#
# [35410 rows x 2 columns], 25:         age                                               text
# 668407   25                CALIFORNIA STARS  An exerpt by B...
# 129104   25             So for my birthday, I signed myself...
# 423608   25                Oh...AND...   it's exactly one m...
# 617476   25         so i was working on my table today, and...
# 222941   25  Yesterdays result: &nbsp; Chocolate DIgestive ...
# ...     ...                                                ...
# 654067   25               starz is bitter because nobody el...
# 204697   25  I read an interesting fact today. The average ...
# 589057   25  We have a pro bono requirement to graduate -- ...
# 167955   25          urlLink     Where do you fall on the l...
# 552074   25  i simply love bebi.  im literally smiling all ...
#
# [29379 rows x 2 columns], 26:         age                                               text
# 449415   26             yeaaaaaaaa riiiiiiite....fun?!?! fu...
# 80473    26         who would have thought after only four ...
# 283824   26                     More available at:  urlLink...
# 595433   26             Views like this are why I moved to ...
# 336859   26  urlLink Theory trading cards!     Handy and fu...
# ...     ...                                                ...
# 24248    26         I added some links on the blog. If anyo...
# 584797   26         Dude, I heard that Dan met Al Borland i...
# 499932   26                   Here's an interesting one:  u...
# 473375   26               Ok- I have to 'man' vent. Why is ...
# 595455   26             Let me just say that cranberry juic...
#
# [24246 rows x 2 columns], 27:         age                                               text
# 322783   27  In my post on Wednesday about Randy Johnson's ...
# 410986   27         To remember to post about the second ha...
# 287619   27                   urlLink LiverpoolFC.tv :  url...
# 29308    27         As of today and now, desire has subside...
# 385174   27  Yeah... I build my webpages for like  urlLink ...
# ...     ...                                                ...
# 506011   27      urlLink    Leaning watertower in Groom, Te...
# 57999    27           Where's Bloop?     &nbsp;   &nbsp;  W...
# 276321   27         Done.  Ended.  Completed.  Finished.  T...
# 661580   27                     Somehow, someway, Chuck Nor...
# 505922   27  urlLink    Mesas as neen from I-40, Western NM...
#
# [20435 rows x 2 columns], 33:         age                                               text
# 407233   33             Well, shit.    One of my favorite R...
# 440479   33  I have been wrestling through this passage in ...
# 318478   33             We wish to see in reality, things i...
# 112267   33  Well today was a very nice day. Cold and raini...
# 619522   33  When I was about 8 I, like many other young gi...
# ...     ...                                                ...
# 200561   33         I got the following email and thought i...
# 435224   33  Since 1 Dec, I pulled my tutorial out from  ur...
# 518976   33  Here is yet another quiz from Debi's blog. Fun...
# 224152   33          urlLink    Kira when she was confirmed...
# 466804   33         I remember, when I was young, being tol...
#
# [7714 rows x 2 columns], 34:         age                                               text
# 642727   34                It's A Boy!   Congratulations to...
# 438391   34  urlLink Estandares: El medio ambiente de las p...
# 560057   34  Gerard Serafin  has a post after my own  heart...
# 188894   34             &nbsp; Well it looks like there is ...
# 98360    34  I want this government to Bail Out America.  S...
# ...     ...                                                ...
# 93029    34  It's official now...I have my grandfather's ol...
# 626879   34                 urlLink  This   is for Tammi.
# 176244   34          urlLink    A friend and early mentor o...
# 40179    34           Feelings of hurt, mis trust, confusio...
# 639240   34  urlLink Miami Valley Hospital Jobs    Also fou...
#
# [9415 rows x 2 columns], 35:         age                                               text
# 288106   35  Brother John emailed me to curse the sports go...
# 201649   35  Having moved back to my home town a couple mon...
# 610204   35  A Nothing Kind Of Day   What a lame Saturday t...
# 317740   35             Wait a minute - what do you mean by...
# 622165   35             yogi's mother fucking cave, baby!  ...
# ...     ...                                                ...
# 671305   35                    Today's Dedication   I have ...
# 482076   35  Hey Gals! I thought I should check in since it...
# 482522   35                   Hi guys!  I'm so stressed, to...
# 482225   35  All this talk reminds me of a country song by ...
# 189216   35  after months of eating nothing and never being...
#
# [7719 rows x 2 columns], 36:         age                                               text
# 162231   36  urlLink Idaho State Journal - Your Views :   '...
# 23499    36  Stock Marke  t     Assessment: negative.  I be...
# 374799   36               Need more action?  urlLink Pornol...
# 647077   36              urlLink HCIRN Reflections: Why is ...
# 632450   36         Indy - Spent the entire weekend with my...
# ...     ...                                                ...
# 571322   36  Moses was right, I need to do this -     1. Wh...
# 183052   36          urlLink    what the hell is it anyway?...
# 396971   36              urlLink Dr Challenges Homosexual a...
# 323826   36             let me steal your thoughts, kiss th...
# 194958   36     Missing marine that was kidnapped, beheaded...
#
# [6294 rows x 2 columns], 37:         age                                               text
# 236412   37             hi, i thought i should update this ...
# 298345   37  urlLink    Here's a pic of my fair city....as ...
# 352509   37              Brand New Nephew   Well, my sister...
# 625041   37          urlLink AK Features: Simen Johan   int...
# 39058    37  posted by Doc Blue                   I realize...
# ...     ...                                                ...
# 490158   37                   An article I first wrote for ...
# 664900   37  I'm sitting in  urlLink Java Joe's  having a $...
# 352428   37  bright and early in the morning, it is..what i...
# 239943   37  Ordinarily I wouldn't see 4 a.m. on a Monday m...
# 240279   37                    urlLink Mark Alexander: Kerr...
#
# [4069 rows x 2 columns], 38:         age                                               text
# 651681   38  From the  urlLink Friday Five , courtesy of He...
# 480628   38  Sorry for not posting for a while. New apartme...
# 652826   38         Check out  urlLink Q&A: the photographi...
# 245144   38  Though I usually hate 60 minutes...and in part...
# 652379   38         I've been out reading blogs to see if t...
# ...     ...                                                ...
# 447873   38  YOU ARE BEING LIED TO Terror Alert Partly Base...
# 101321   38  WAKE UP AND SEE   Waking up my skies are gray ...
# 28213    38               Why Real Networks' dispute with A...
# 180942   38  The May preview of Visual Studio 2005 (Whidbey...
# 447904   38  Well it appears the Bush adminstration have se...
#
# [3195 rows x 2 columns], 39:         age                                               text
# 450163   39  My friend Popcorn took me to dinner last night...
# 390794   39  The day before we left for Dallas I was unplug...
# 286526   39      We'd both be so spent by the end of the ev...
# 74040    39         Here's a copy of the lawsuit.   urlLink...
# 670217   39                    urlLink Microsoft's strange ...
# ...     ...                                                ...
# 450148   39  Part of last nights dream has me befuddled.  I...
# 27753    39  Ever felt as if some days your life was like a...
# 670237   39                    urlLink BT suggests using ph...
# 130731   39  urlLink The New York Times > Week in Review > ...
# 451227   39  The 'Niger/Iraq Uranium Connection' is rearing...
#
# [2404 rows x 2 columns], 40:         age                                               text
# 578762   40  OIF  &#151; Spc. Rian C. Ferguson, 22, of Tayl...
# 579378   40  OIF  &#151; Cpl. Daniel R. Amaya, 22, of Odess...
# 511967   40  RPEBW To Speed Construction of Offshore Wind T...
# 82712    40  urlLink    LAUGH-A-MINUTE RUMSFELD BECOMES A C...
# 82692    40  urlLink Yahoo! News - Vegas Casino Boots Singe...
# ...     ...                                                ...
# 579051   40  OIF  &#151; Sgt. 1st Class John W. Marshall, 5...
# 579462   40  OIF  &#151; 2nd Lt. Seth J. Dvorin, 24, of New...
# 287784   40     It seems that The Honz is on vacation all t...
# 579607   40  OEF  &#151; Army Capt. Bartt D. Owens, 31, of ...
# 500743   40  OH, MY CITY OF ANGELS!  MY BELL TOLLS FOR THEE...
#
# [2171 rows x 2 columns], 41:         age                                               text
# 326020   41  Well, I  guess  it was a success. I thought ev...
# 485849   41  This one's a hoot....strange fiction   Jen com...
# 141402   41  By Rex Reed, no less. I wish I could write lik...
# 485144   41  YAY!  I JUST INHERITED 14 MILLION DOLLARS ( ag...
# 159661   41             I thought I would share some of our...
# ...     ...                                                ...
# 207490   41     this is just one of those hot lazy summer h...
# 138851   41  I exchange email with a cousin of mine who liv...
# 213681   41  I have a rainbow sticker on my car.  I will al...
# 239673   41          urlLink Family values alert!   I don't...
# 660017   41  That Was Fast...  All I did was innocently ask...
#
# [1624 rows x 2 columns], 42:         age                                               text
# 372960   42                    urlLink    My and My little ...
# 676857   42  urlLink ANTIQUITIES OF THE ILLUMINATI v 4.5.1....
# 348947   42              Heart of a Worm.     Against all o...
# 629628   42         As we're not part of the world as such,...
# 676657   42  urlLink Welcome to Earth: meet the leaders  Th...
# ...     ...                                                ...
# 22150    42  Right! One more day to go before I begin going...
# 78352    42  urlLink    Apr 6, 2004 - Passover Seder - Shai...
# 677052   42          urlLink There's a rainbow in every tea...
# 677546   42          urlLink Aliens Exist  Yes, it is a fac...
# 96329    42  urlLink    This bridge over the New River Gorg...
#
# [1307 rows x 2 columns], 43:         age                                               text
# 130482   43  While walking to the library to use the free i...
# 402829   43  There was a really attractive, somewhat shy, b...
# 248068   43         In  urlLink Dan Savage's column  last T...
# 248000   43  All other things being equal, I am a breast ma...
# 247947   43  Master   Some things are best left in fantasy,...
# ...     ...                                                ...
# 621464   43              Monday Morning!  'The Boy' is off ...
# 285062   43  7:03 a.m. Thursday, Day 32.  Okay, yesterday s...
# 476722   43                urlLink NathanNewman.org - News ...
# 47477    43         Today is a great day for me that god. B...
# 297461   43  I just finished watching Dr. Phil's show (well...
#
# [1873 rows x 2 columns], 44:         age                                               text
# 333520   44  About five years ago, I found myself driving h...
# 76485    44         A good friend of mine who read my blog ...
# 351939   44                urlLink    Cindi at McDonalds on...
# 202503   44  Internationalist versus Nationalist     DISCOV...
# 63101    44                   I am eliminating the subject'...
# ...     ...                                                ...
# 321248   44  If I had a penny for every person who I hear k...
# 351859   44         urlLink    Prototype for TB1&nbsp; urlLink
# 333500   44  I cannot remember his name. I cannot remember ...
# 137337   44         I´m on my vacation now, things are work...
# 202501   44  June 12 2004  I WANT TO THANK YOU FOR REPSONDI...
#
# [879 rows x 2 columns], 45:         age                                               text
# 65748    45         The internet is a free, open resource. ...
# 18545    45  In yet another attempt to get the world to spi...
# 18551    45  EXCERPTS FROM 'POLICE STATE USA,' a recent col...
# 628242   45  Salon.com  The confessions of a semi-successfu...
# 628218   45  The 2004 - 2005 Reading Group Suggestions Book...
# ...     ...                                                ...
# 106183   45  'Trust your hunches. They're usually based on ...
# 439159   45  Hello. It's been a while since I've done a pos...
# 35172    45             My children love my movie choices.&...
# 649417   45  urlLink  eBay item  1751145185 (Ends  Jul-25-0...
# 650051   45          urlLink Calendar Converter  - I cannot...
#
# [1946 rows x 2 columns], 46:         age                                               text
# 455506   46  It's a Todd kind of day!! : )  Yeah, I'm home-...
# 351705   46                 Today, from The Net    It's the...
# 644997   46                urlLink    Nick in line waiting ...
# 455815   46  Good morning everybody!  I forgot to set my VC...
# 455829   46  Fox Hottie Alert!!  Jeff G was just on Fox New...
# ...     ...                                                ...
# 157980   46  Well, yesterday afternoon, I thought to myself...
# 644599   46  In Memory of our beloved Laurel........Gone bu...
# 644545   46  Today's prayer: 'Dear Lord, since I have disco...
# 644544   46  Tonight , I came home from work hot, sticky, m...
# 644795   46               Our puppy Bitsy turns one today! ...
#
# [1191 rows x 2 columns], 47:         age                                               text
# 144036   47  I'm in D.C but I've been spending a lot of tim...
# 138534   47                Woman needs our help   A woman h...
# 255889   47  urlLink Mr. Standfast  is hosting the 27th Chr...
# 368634   47  A 'China Letter'  Digest of News items that ar...
# 122691   47               With the death of my brother last...
# ...     ...                                                ...
# 255995   47         Today is the feast day of St. Martha, t...
# 179506   47  When I pray, you strengthen me When I love ano...
# 144053   47         Yes, really.  urlLink Jerome Conley  is...
# 368523   47  The following is the text of a letter sent by ...
# 21737    47  Before you debate me read this:      http://ww...
#
# [967 rows x 2 columns], 48:         age                                               text
# 619990   48  ok, so the trip to spain is on a countdown- le...
# 342824   48      urlLink    ENJOY (Marie et kay)&nbsp; urlL...
# 80797    48  I wasn't feeling the opening ceremonies of the...
# 48426    48             Does your Needs marker (the circle)...
# 621026   48         ok, so mm has new glasses....which look...
# ...     ...                                                ...
# 621077   48         ok, so last night the c-w's finally ren...
# 190561   48  I have been feeling quite asunder these last t...
# 522625   48  We're leaving as soon as I get the truck loade...
# 619845   48  ok, so we sat and watched the first part of th...
# 601532   48  Hi All! Dave got up early today to butcher chi...
#
# [1570 rows x 2 columns]}

# %%
# Same range as in pan13 dataset

dataframes_10s = []
dataframes_20s = []
dataframes_30s = []
dataframes_40s = []

for key, value in age_dict.items():
  if 13 <= int(key) <= 17:
    dataframes_10s.append(value)
  elif 23 <= int(key) <= 27:
    dataframes_20s.append(value)
  elif 33 <= int(key) <= 37:
    dataframes_30s.append(value)
  elif 43 <= int(key) <= 47:
    dataframes_40s.append(value)

df_10s = pd.concat(dataframes_10s)
df_20s = pd.concat(dataframes_20s)
df_30s = pd.concat(dataframes_30s)
df_40s = pd.concat(dataframes_40s)

all_dataframes = [df_10s, df_20s, df_30s, df_40s]

min_len = len(all_dataframes[0])

for df in all_dataframes:
  if len(df) < min_len:
    min_len = len(df)

df_10s["age"] = 0
df_20s["age"] = 1
df_30s["age"] = 2
df_40s['age'] = 3

all_dataframes = [df_10s.sample(min_len), df_20s.sample(min_len), df_30s.sample(min_len), df_40s.sample(min_len)]


df = pd.concat(all_dataframes)

# %%
df
# Out:
#         age                                               text
# 137683    0  haiyo~.Today weather very bad sia. Early morni...
# 490884    0  *whimpers* Sorry, Laura, got pulled off the in...
# 169978    0         the time we spend together its the happ...
# 168156    0             i was absolutely unable to comprehe...
# 554569    0                   Poe's cool :p  What did you h...
# ...     ...                                                ...
# 351883    3      urlLink    Meet Greg Schindel, a great guy...
# 107783    3  A Stray Thought    By Henrietta Asher Handy Co...
# 216026    3  We will be discussing sparcworks for the Sun B...
# 115127    3         Last night I tried to get on and tell m...
# 236953    3  Howdy from Duck Ditch USA where the trees are ...
#
# [27424 rows x 2 columns]

# %% [markdown]
# ## 3. Create n_grams from the text (Optional)

# %%
# lemmatizing function
def lemmatize(text):
    lemmatizer = WordNetLemmatizer()
    text = [lemmatizer.lemmatize(word) for word in text]
    return text

# remove stopwords
def remove_stopwords(text):
    stopword = nltk.corpus.stopwords.words('english')
    text = [word for word in text if word not in stopword]
    return text
    
def tokenize(text):
    wrong_words = ["urllink", "nbsp"]
    tokens = [token for token in text.split(" ") if token != "" and token not in wrong_words]
    return tokens

def lowered(s):
    return s.lower()

def remove_nonalph(s):
      s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
      return s

def generate_ngrams(s, n):
    # Use the zip function to help us generate n-grams
    # Concatentate the tokens into ngrams and return
    ngrams = zip(*[s[i:] for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

# %%
df["text"] = df["text"].apply(lowered).apply(remove_nonalph).apply(tokenize)
print(df['text'].iloc[0])
print(df['text'])
# Out:
# ['haiyo', 'today', 'weather', 'very', 'bad', 'sia', 'early', 'morning', 'rain', 'make', 'me', 'so', 'sian', 'today', 'go', 'school', 'kinda', 'special', 'because', 'this', 'is', 'the', 'first', 'time', 'i', 'took', 'bus', 'to', 'school', 'for', 'this', 'year', 'thing', 'was', 'kinda', 'different', 'now', 'a', 'days', 'in', 'the', 'bus', 'interchange', 'there', 'was', 'a', 'very', 'long', 'que', 'in', 'one', 'of', 'the', 'berth', 'never', 'seen', 'that', 'before', 'it', 'was', 'very', 'long', 'other', 'different', 'thing', 'is', 'that', 'our', 'school', 'student', 'does', 'not', 'wait', 'at', 'the', 'bus', 'stop', 'anymore', 'they', 'tend', 'to', 'wait', 'at', 'one', 'corner', 'of', 'the', 'interchange', 'when', 'the', 'bus', 'come', 'they', 'kinda', 'cut', 'que', 'maybe', 'for', 'today', 'i', 'saw', 'this', 'situation', 'bah', 'special', 'case', 'ahahaha', 'saw', 'benjamin', 'and', 'wei', 'tian', 'on', 'the', 'bus', 'the', 'bus', 'was', 'so', 'crowded', 'with', 'people', 'hardly', 'any', 'big', 'movement', 'when', 'we', 'reach', 'the', 'bus', 'stop', 'ben', 'awt', 'and', 'me', 'saw', 'danial', 'went', 'to', 'him', 'because', 'he', 'got', 'an', 'umbrella', 'with', 'him', 'u', 'should', 'know', 'whats', 'next', 'p', 'hmmm', 'today', 'english', 'lesson', 'was', 'kind', 'of', 'surprize', 'intially', 'i', 'thought', 'that', 'arguementative', 'writing', 'was', 'discussion', 'and', 'discussion', 'writing', 'was', 'arguementative', 'i', 'was', 'stunned', 'when', 'teacher', 'revise', 'this', 'with', 'the', 'class', 'during', 'chinese', 'lesson', 'more', 'fun', 'watch', 'a', 'movie', 'about', 'a', 'chinese', 'girl', 'and', 'crap', 'after', 'that', 'me', 'and', 'a', 'group', 'of', 'friend', 'so', 'bad', 'haben', 'greet', 'teacher', 'then', 'we', 'went', 'for', 'recess', 'x', 'lucky', 'that', 'he', 'did', 'not', 'mind', 'on', 'this', 'orelse', 'we', 'all', 'will', 'be', 'in', 'deep', 'trouble', 'after', 'school', 'was', 'more', 'fun', 'spy', 'felix', 'awt', 'and', 'me', 'help', 'the', 'school', 'save', 'electricity', 'our', 'school', 'toilet', 'lights', 'are', 'on', 'by', 'the', 'senor', 'we', 'went', 'around', 'the', 'school', 'see', 'toilet', 'with', 'no', 'lights', 'on', 'we', 'went', 'in', 'and', 'the', 'light', 'operated', 'wooohoooo', 'save', 'money', 'for', 'the', 'school', 'huh', 'so', 'noble', 'of', 'us', 'at', '3pm', 'went', 'for', 'the', 'social', 'studies', 'remedial', 'after', 'that', 'spy', 'binghuan', 'and', 'me', 'went', 'to', 'play', 'ping', 'pong', 'play', 'play', 'and', 'play', 'we', 'had', 'so', 'much', 'fun', 'until', 'around', '6pm', 'then', 'we', 'stoppped', 'and', 'we', 'went', 'home', 'just', 'finish', 'my', 'dinner', 'and', 'login', 'to', 'update', 'this', 'piece', 'of', 'entry', 'thats', 'all', 'folks', 'contented', 'boy']
# 137683    [haiyo, today, weather, very, bad, sia, early,...
# 490884    [whimpers, sorry, laura, got, pulled, off, the...
# 169978    [the, time, we, spend, together, its, the, hap...
# 168156    [i, was, absolutely, unable, to, comprehend, t...
# 554569    [poe, s, cool, p, what, did, you, have, to, do...
#                                 ...
# 351883    [meet, greg, schindel, a, great, guy, he, s, t...
# 107783    [a, stray, thought, by, henrietta, asher, hand...
# 216026    [we, will, be, discussing, sparcworks, for, th...
# 115127    [last, night, i, tried, to, get, on, and, tell...
# 236953    [howdy, from, duck, ditch, usa, where, the, tr...
# Name: text, Length: 27424, dtype: object

# %%
df.index = range(len(df))

# %% [markdown]
# Pre processing data loader

# %%
class_choice = 'age'
classdict = defaultdict(int)

for row in df[class_choice]:
  classdict[row] += 1
print(sorted(classdict))

### PROBLEM: ALS IK DIT WISSEL NAAR NORMAL SORT DAN IS DE UITKOMST INEENS ANDERS???
classdict = dict(sorted(classdict.items(), key=operator.itemgetter(1), reverse=True))
#classdict = dict(sorted(classdict.items()))
print('classdict:')
print(classdict)
# Out:
# [0, 1, 2, 3]
# classdict:
# {0: 6856, 1: 6856, 2: 6856, 3: 6856}

# %% [markdown]
# ## 7. Vocabulary dictionary
# Making a dict of all the words in the dataset and mapping each unique word to a unique number

# %%
vocabdict = defaultdict(int)   

for row in df['text']:
  for n_gram in row:
    n_gram = n_gram.lower()
    vocabdict[n_gram] += 1

vocabdict = dict(sorted(vocabdict.items(), key=operator.itemgetter(1), reverse=True))
print(vocabdict)
# Out:
# {'the': 254817, 'i': 215482, 'to': 175678, 'and': 160680, 'a': 131459, 'of': 115200, 'it': 83667, 'in': 83553, 'that': 82655, 'is': 64243, 'you': 58871, 'my': 56972, 'for': 55153, 's': 54184, 'was': 49705, 'on': 44710, 't': 40052, 'with': 38730, 'this': 38336, 'have': 38279, 'but': 37303, 'me': 37176, 'so': 34776, 'we': 34545, 'be': 33931, 'he': 32818, 'not': 30544, 'at': 30296, 'as': 29571, 'all': 26507, 'are': 26167, 'they': 24653, 'just': 21731, 'like': 21553, 'out': 21523, 'up': 21356, 'what': 21260, 'about': 20932, 'she': 20903, 'or': 20607, 'from': 20590, 'm': 20544, 'one': 20380, 'can': 20180, 'her': 19532, 'if': 19317, 'there': 18531, 'do': 18386, 'had': 18246, 'will': 17945, 'when': 17303, 'his': 17202, 'by': 16715, 'get': 16451, 'time': 15426, 'an': 14968, 'no': 14655, 'some': 14422, 'now': 14300, 'know': 14257, 'who': 14210, 'more': 13838, 'would': 13671, 'your': 13636, 'has': 13292, 'then': 13281, 'don': 13146, 'people': 12279, 'am': 12269, 'been': 12230, 'him': 12044, 'go': 11910, 'really': 11881, 'were': 11790, 'them': 11719, 'how': 11691, 'think': 11656, 'well': 11585, 'good': 11314, 'our': 10702, 'their': 10674, 'back': 10464, 'day': 10282, 'going': 10118, 'got': 10055, 'because': 10028, 'see': 9636, 'love': 9621, 'which': 9074, 'here': 8999, 'only': 8972, 'much': 8933, 'other': 8731, 've': 8692, 'into': 8646, 'over': 8578, 'even': 8383, 'us': 8145, 'way': 8126, 'want': 8115, 'could': 8083, 'today': 8055, 'said': 7980, 'too': 7957, 'after': 7928, 'new': 7832, 'll': 7733, 'than': 7592, 'last': 7580, 'life': 7575, 'did': 7554, 'very': 7483, 'off': 7168, 'work': 7137, 'still': 7118, 'make': 7098, 'things': 6993, 'first': 6979, 'say': 6962, 'right': 6806, 'went': 6779, 're': 6718, 'something': 6661, 'little': 6503, 'down': 6492, 'also': 6482, 'where': 6367, 'being': 6214, 'never': 6200, 'why': 6148, 'any': 6016, 'night': 5989, 'its': 5948, 'two': 5932, 'around': 5833, 'again': 5825, 'take': 5777, 'thing': 5769, 'before': 5760, '2': 5727, 'home': 5678, 'd': 5663, 'most': 5576, 'those': 5560, 'need': 5553, 'should': 5455, 'feel': 5446, 'these': 5387, 'didn': 5326, 'while': 5178, 'long': 4921, 'god': 4878, 'great': 4791, 'many': 4786, 'year': 4755, 'made': 4751, 'come': 4730, 'years': 4710, 'world': 4690, 'another': 4578, 'always': 4532, 'through': 4451, 'let': 4379, 'thought': 4342, '3': 4340, 'few': 4330, 'since': 4285, 'better': 4270, 'ever': 4262, 'oh': 4163, '1': 4163, 'week': 4135, 'look': 4129, 'may': 4123, 'next': 4120, 'though': 4095, 'house': 4031, 'school': 3989, 'find': 3976, 'days': 3969, 'myself': 3953, 'old': 3942, 'man': 3933, 'every': 3899, 'told': 3889, 'maybe': 3883, 'read': 3846, 'sure': 3823, 'away': 3773, 'someone': 3749, 'getting': 3745, 'lot': 3710, 'bad': 3695, 'same': 3687, 'tell': 3590, 'friends': 3589, 'actually': 3584, 'doing': 3579, 'own': 3574, 'best': 3533, '4': 3493, 'put': 3492, 'came': 3461, 'left': 3434, 'blog': 3417, 'anything': 3404, 'does': 3383, 'such': 3315, 'place': 3287, 'nothing': 3280, 'enough': 3273, '5': 3242, 'big': 3239, 'give': 3233, 'end': 3231, 'fun': 3192, 'everyone': 3177, 'u': 3167, 'until': 3160, 'done': 3124, 'having': 3116, 'pretty': 3111, 'morning': 3088, 'keep': 3080, 'hope': 3077, 'found': 3062, 'book': 3053, 'stuff': 3024, 'part': 2979, 'friend': 2972, 'post': 2937, 'yet': 2925, 'times': 2924, 'everything': 2898, 'help': 2888, 'guess': 2885, 'person': 2885, 'yes': 2860, 'called': 2859, 'looking': 2831, 'hard': 2825, 'once': 2822, 'nice': 2799, 'without': 2776, 'mean': 2774, 'each': 2771, 'least': 2758, 'might': 2758, 'trying': 2754, 'doesn': 2716, 'call': 2705, 'took': 2701, 'must': 2688, 'ok': 2683, 'both': 2682, 'guy': 2673, 'happy': 2665, 'try': 2659, 'talk': 2656, 'anyway': 2655, 'im': 2649, 'show': 2643, 'family': 2637, 'use': 2618, 'three': 2604, 'bit': 2600, 'wanted': 2577, 'later': 2566, 'started': 2557, '10': 2532, 'believe': 2525, 'else': 2502, 'start': 2498, 'money': 2476, 'name': 2475, 'whole': 2473, 'live': 2470, 'mind': 2468, 'course': 2466, ' ...

# %%
# WORD TO NUMBER MAPPING
l = list(vocabdict.keys())
wordmap = dict([(y,x) for x,y in enumerate(l)])
print(wordmap)
# Out:
# {'the': 0, 'i': 1, 'to': 2, 'and': 3, 'a': 4, 'of': 5, 'it': 6, 'in': 7, 'that': 8, 'is': 9, 'you': 10, 'my': 11, 'for': 12, 's': 13, 'was': 14, 'on': 15, 't': 16, 'with': 17, 'this': 18, 'have': 19, 'but': 20, 'me': 21, 'so': 22, 'we': 23, 'be': 24, 'he': 25, 'not': 26, 'at': 27, 'as': 28, 'all': 29, 'are': 30, 'they': 31, 'just': 32, 'like': 33, 'out': 34, 'up': 35, 'what': 36, 'about': 37, 'she': 38, 'or': 39, 'from': 40, 'm': 41, 'one': 42, 'can': 43, 'her': 44, 'if': 45, 'there': 46, 'do': 47, 'had': 48, 'will': 49, 'when': 50, 'his': 51, 'by': 52, 'get': 53, 'time': 54, 'an': 55, 'no': 56, 'some': 57, 'now': 58, 'know': 59, 'who': 60, 'more': 61, 'would': 62, 'your': 63, 'has': 64, 'then': 65, 'don': 66, 'people': 67, 'am': 68, 'been': 69, 'him': 70, 'go': 71, 'really': 72, 'were': 73, 'them': 74, 'how': 75, 'think': 76, 'well': 77, 'good': 78, 'our': 79, 'their': 80, 'back': 81, 'day': 82, 'going': 83, 'got': 84, 'because': 85, 'see': 86, 'love': 87, 'which': 88, 'here': 89, 'only': 90, 'much': 91, 'other': 92, 've': 93, 'into': 94, 'over': 95, 'even': 96, 'us': 97, 'way': 98, 'want': 99, 'could': 100, 'today': 101, 'said': 102, 'too': 103, 'after': 104, 'new': 105, 'll': 106, 'than': 107, 'last': 108, 'life': 109, 'did': 110, 'very': 111, 'off': 112, 'work': 113, 'still': 114, 'make': 115, 'things': 116, 'first': 117, 'say': 118, 'right': 119, 'went': 120, 're': 121, 'something': 122, 'little': 123, 'down': 124, 'also': 125, 'where': 126, 'being': 127, 'never': 128, 'why': 129, 'any': 130, 'night': 131, 'its': 132, 'two': 133, 'around': 134, 'again': 135, 'take': 136, 'thing': 137, 'before': 138, '2': 139, 'home': 140, 'd': 141, 'most': 142, 'those': 143, 'need': 144, 'should': 145, 'feel': 146, 'these': 147, 'didn': 148, 'while': 149, 'long': 150, 'god': 151, 'great': 152, 'many': 153, 'year': 154, 'made': 155, 'come': 156, 'years': 157, 'world': 158, 'another': 159, 'always': 160, 'through': 161, 'let': 162, 'thought': 163, '3': 164, 'few': 165, 'since': 166, 'better': 167, 'ever': 168, 'oh': 169, '1': 170, 'week': 171, 'look': 172, 'may': 173, 'next': 174, 'though': 175, 'house': 176, 'school': 177, 'find': 178, 'days': 179, 'myself': 180, 'old': 181, 'man': 182, 'every': 183, 'told': 184, 'maybe': 185, 'read': 186, 'sure': 187, 'away': 188, 'someone': 189, 'getting': 190, 'lot': 191, 'bad': 192, 'same': 193, 'tell': 194, 'friends': 195, 'actually': 196, 'doing': 197, 'own': 198, 'best': 199, '4': 200, 'put': 201, 'came': 202, 'left': 203, 'blog': 204, 'anything': 205, 'does': 206, 'such': 207, 'place': 208, 'nothing': 209, 'enough': 210, '5': 211, 'big': 212, 'give': 213, 'end': 214, 'fun': 215, 'everyone': 216, 'u': 217, 'until': 218, 'done': 219, 'having': 220, 'pretty': 221, 'morning': 222, 'keep': 223, 'hope': 224, 'found': 225, 'book': 226, 'stuff': 227, 'part': 228, 'friend': 229, 'post': 230, 'yet': 231, 'times': 232, 'everything': 233, 'help': 234, 'guess': 235, 'person': 236, 'yes': 237, 'called': 238, 'looking': 239, 'hard': 240, 'once': 241, 'nice': 242, 'without': 243, 'mean': 244, 'each': 245, 'least': 246, 'might': 247, 'trying': 248, 'doesn': 249, 'call': 250, 'took': 251, 'must': 252, 'ok': 253, 'both': 254, 'guy': 255, 'happy': 256, 'try': 257, 'talk': 258, 'anyway': 259, 'im': 260, 'show': 261, 'family': 262, 'use': 263, 'three': 264, 'bit': 265, 'wanted': 266, 'later': 267, 'started': 268, '10': 269, 'believe': 270, 'else': 271, 'start': 272, 'money': 273, 'name': 274, 'whole': 275, 'live': 276, 'mind': 277, 'course': 278, 'head': 279, 'lol': 280, 'probably': 281, 'used': 282, 'yeah': 283, 'anyone': 284, 'remember': 285, 'job': 286, 'saw': 287, 'room': 288, 'kind': 289, 'won': 290, 'far': 291, 'point': 292, 'already': 293, 'asked': 294, 'news': 295, 'story': 296, 'bush': 297, 'movie': 298, 'says': 299, 'car': 300, 'makes': 301, 'real': 302, 'almost': 303, 'able': 304, 'fact': 305, 'quite': 306, 'feeling': 307, 'hours': 308, 'tomorrow': 309, 'com': 310, 'finally': 311, 'yesterday': 312, 'high': 31 ...

# %% [markdown]
# ## 8. Mapping text column to numbers (tensor)

# %%
import numpy as np
text_int_list = []
text_lengths = []
for i, text in enumerate(df['text']):
  newtext = []
  lens = []
  for word in text:
    newtext.append(int(wordmap[word]))
  text_lengths.append(len(newtext))
  text_int_list.append(newtext)
average_len = int(sum(text_lengths) / len(text_lengths))
df["lengths"] = text_lengths

encoding_padded = []
for ints in text_int_list:
  N = average_len
  zeros = np.zeros(N, dtype=int)
  encoded = zeros
  length = min(N, len(ints))
  encoded[:length] = ints[:length]
  encoding_padded.append(np.array((encoded, len(ints))))

df["encoded"] = encoding_padded
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#        age  ...                                            encoded
# 0        0  ...  [[19807, 101, 919, 111, 192, 4000, 453, 222, 9...
# 1        0  ...  [[59709, 450, 2699, 84, 1311, 112, 0, 648, 149...
# 2        0  ...  [[0, 54, 23, 614, 335, 132, 0, 9083, 1, 93, 16...
# 3        0  ...  [[1, 14, 1161, 2604, 2, 7531, 0, 1264, 101, 0,...
# 4        0  ...  [[10041, 13, 323, 460, 36, 110, 10, 19, 2, 47,...
# ...    ...  ...                                                ...
# 27419    3  ...  [[615, 1315, 113870, 4, 152, 255, 25, 13, 0, 1...
# 27420    3  ...  [[4, 8379, 163, 52, 36764, 19355, 5021, 2729, ...
# 27421    3  ...  [[23, 49, 24, 3328, 113871, 12, 0, 707, 7188, ...
# 27422    3  ...  [[108, 131, 1, 485, 2, 53, 15, 3, 194, 11, 366...
# 27423    3  ...  [[10554, 40, 4387, 6797, 2102, 126, 0, 1941, 3...
#
# [27424 rows x 4 columns]

# %%
X = list(df['encoded'])
y = list(df['age'])
print(X[0])
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2)
# Out:
# [array([19807,   101,   919,   111,   192,  4000,   453,   222,   961,
#          115,    21,    22,  6516,   101,    71,   177,   595,   626,
#           85,    18,     9,     0,   117,    54,     1,   251,   957,
#            2,   177,    12,    18,   154,   137,    14,   595,   320,
#           58,     4,   179,     7,     0,   957, 16954,    46,    14,
#            4,   111,   150,  1601,     7,    42,     5,     0, 24177,
#          128,   348,     8,   138,     6,    14,   111,   150,    92,
#          320,   137,     9,     8,    79,   177,  1216,   206,    26,
#          384,    27,     0,   957,   325,   650,    31,  1538,     2,
#          384,    27,    42,  1510,     5,     0, 16954,    50,     0,
#          957,   156,    31,   595,   677,  1601,   185,    12,   101,
#            1,   287,    18,   791,  4863,   626,   491, 20974,   287,
#         9433,     3,  8580, 13896,    15,     0,   957,     0,   957,
#           14,    22,  5012,    17,    67,  1815,   130,   212,  2065,
#           50,    23,  1259,     0,   957,   325,  1462, 37065,     3,
#           21,   287, 59705,   120,     2,    70,    85,    25,    84,
#           55,  7222,    17,    70,   217,   145,    59,  2738,   174,
#          460,  1757,   101,   722,  1520,    14,   289,     5, 44670,
#        59706,     1,   163,     8, 37066,   451,    14,  1636,     3,
#         1636,   451,    14, 37066,     1,    14,  6916,    50,   905,
#        11880,    18,    17,     0,   383,   356,   808,  1520,    61,
#          215,   349,     4,   298,    37,     4,   808,   315,     3,
#          814,   104,     8,    21,     3,     4,   430,     5,   229,
#           22,   192, 16199,  7529,   905,    65,    23,   120,    12,
#        10257,   589,  1224,     8,    25,   110,    26,   277,    15,
#           18])
#  342]

# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import re
import spacy
from collections import Counter
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import string
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from sklearn.metrics import mean_squared_error
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class BlogDataset(Dataset):
    def __init__(self, X, Y):
        self.X = X
        self.y = Y
        
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        return torch.from_numpy(self.X[idx][0].astype(np.int32)), self.y[idx], self.X[idx][1]

# %%
train_ds = BlogDataset(X_train, y_train)
valid_ds = BlogDataset(X_valid, y_valid)

# %% [markdown]
# **TO-DO:**
#
# *   Confusion matrix
# *   Activation words

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# confusion matrix plot function
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    import itertools
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.savefig('/content/drive/MyDrive/Language, speech and dialogue processing/Blog_rnn_confusion_matrix.png')

# %%
def train_model(model, epochs=10, lr=0.001):
    parameters = filter(lambda p: p.requires_grad, model.parameters())
    optimizer = torch.optim.Adam(parameters, lr=lr)
    for i in range(epochs):
        model.train()
        sum_loss = 0.0
        total = 0
        for x, y, l in train_dl:
            x = x.long().to(device)
            y = y.long().to(device)
            l = l.to(device)
            y_pred = model(x, l)
            optimizer.zero_grad()
            x, y, l = x.to(device), y.to(device), l.to(device)
            loss = F.cross_entropy(y_pred, y).to(device)
            loss.backward()
            optimizer.step()
            sum_loss += loss.item()*y.shape[0]
            total += y.shape[0]
        val_loss, val_acc, val_rmse = validation_metrics(model, val_dl)
        train_loss = sum_loss/total
        print('Epoch: %d' %(i + 1))
        print(f'\tLoss: {train_loss:.4f}(train)\t')
        print(f'\tLoss: {val_loss:.4f}(valid)\t|\tAcc: {val_acc * 100:.1f}%(valid) | \tRMSE: {val_rmse * 100:.1f}(valid)')
        if i == (epochs-1):
          predictions, labels = validation_metrics(model, val_dl, True)
          conf_matrix = confusion_matrix(np.array(labels), np.array(predictions), labels=[0, 1, 2, 3])
          np.set_printoptions(precision=2)
          # Plot non-normalized confusion matrix
          #plt.figure()
          plot_confusion_matrix(conf_matrix, classes=['10s', '20s', '30s', '40s'], normalize=True, title='Blog RNN Confusion matrix, with normalization')



def validation_metrics (model, valid_dl, last_epoch=False):
    model.eval()
    correct = 0
    total = 0
    sum_loss = 0.0
    sum_rmse = 0.0
    predictions = []
    labels = []
    for x, y, l in valid_dl:
        x,y,l = x.to(device), y.to(device), l.to(device)
        x = x.long()
        y = y.long()
        y_hat = model(x, l)
        loss = F.cross_entropy(y_hat, y)
        pred = y_hat.argmax(1)
        predict = pred.to('cpu')
        label = y.to('cpu')
        predictions.extend(predict)
        labels.extend(label)
        correct += (pred == y).float().sum()
        total += y.shape[0]
        sum_loss += loss.item()*y.shape[0]
        sum_rmse += np.sqrt(mean_squared_error(pred.cpu(), y.unsqueeze(-1).cpu()))*y.shape[0]
    if last_epoch == False:
      return sum_loss/total, correct/total, sum_rmse/total
    else:
      return predictions, labels

# %%
batch_size = 256
vocab_size = len(vocabdict)
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_dl = DataLoader(valid_ds, batch_size=batch_size)

# %%
class LSTM_fixed_len(torch.nn.Module) :
    def __init__(self, vocab_size, embedding_dim, hidden_dim) :
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.linear = nn.Linear(hidden_dim, 5)
        self.dropout = nn.Dropout(0.2)
        
    def forward(self, x, l):
        x = self.embeddings(x)
        x = self.dropout(x)
        lstm_out, (ht, ct) = self.lstm(x)
        return self.linear(ht[-1])

# %%
print(f"Vocab size: {vocab_size}")

# Rule of thumb voor embed dim volgens: 
# (https://datascience.stackexchange.com/questions/31109/ratio-between-embedded-vector-dimensions-and-vocabulary-size)

embedding_dimensions =  int(vocab_size**0.25)

model_fixed =  LSTM_fixed_len(vocab_size, embedding_dimensions, 50).to(device)
# Out:
# Vocab size: 113881

# %%
train_model(model_fixed, epochs=50, lr=0.01)
# Out:
# Epoch: 1
# 	Loss: 1.4012(train)
# 	Loss: 1.3901(valid)	|	Acc: 25.5%(valid) | 	RMSE: 184.3(valid)
# Epoch: 2
# 	Loss: 1.3863(train)
# 	Loss: 1.3906(valid)	|	Acc: 26.3%(valid) | 	RMSE: 135.7(valid)
# Epoch: 3
# 	Loss: 1.3735(train)
# 	Loss: 1.3900(valid)	|	Acc: 27.2%(valid) | 	RMSE: 176.7(valid)
# Epoch: 4
# 	Loss: 1.3451(train)
# 	Loss: 1.3477(valid)	|	Acc: 33.3%(valid) | 	RMSE: 136.9(valid)
# Epoch: 5
# 	Loss: 1.2512(train)
# 	Loss: 1.3003(valid)	|	Acc: 37.4%(valid) | 	RMSE: 136.2(valid)
# Epoch: 6
# 	Loss: 1.1269(train)
# 	Loss: 1.2882(valid)	|	Acc: 39.5%(valid) | 	RMSE: 124.4(valid)
# Epoch: 7
# 	Loss: 1.0394(train)
# 	Loss: 1.3226(valid)	|	Acc: 41.1%(valid) | 	RMSE: 111.2(valid)
# Epoch: 8
# 	Loss: 0.9598(train)
# 	Loss: 1.3503(valid)	|	Acc: 41.5%(valid) | 	RMSE: 112.9(valid)
# Epoch: 9
# 	Loss: 0.8907(train)
# 	Loss: 1.3623(valid)	|	Acc: 41.2%(valid) | 	RMSE: 109.5(valid)
# Epoch: 10
# 	Loss: 0.8224(train)
# 	Loss: 1.4031(valid)	|	Acc: 40.5%(valid) | 	RMSE: 111.9(valid)
# Epoch: 11
# 	Loss: 0.7520(train)
# 	Loss: 1.4745(valid)	|	Acc: 40.5%(valid) | 	RMSE: 108.1(valid)
# Epoch: 12
# 	Loss: 0.6956(train)
# 	Loss: 1.5452(valid)	|	Acc: 40.6%(valid) | 	RMSE: 106.9(valid)
# Epoch: 13
# 	Loss: 0.6342(train)
# 	Loss: 1.6211(valid)	|	Acc: 41.3%(valid) | 	RMSE: 109.2(valid)
# Epoch: 14
# 	Loss: 0.5849(train)
# 	Loss: 1.6728(valid)	|	Acc: 42.2%(valid) | 	RMSE: 108.4(valid)
# Epoch: 15
# 	Loss: 0.5435(train)
# 	Loss: 1.7365(valid)	|	Acc: 41.8%(valid) | 	RMSE: 106.3(valid)
# Epoch: 16
# 	Loss: 0.5018(train)
# 	Loss: 1.8313(valid)	|	Acc: 41.3%(valid) | 	RMSE: 108.0(valid)
# Epoch: 17
# 	Loss: 0.4666(train)
# 	Loss: 1.8809(valid)	|	Acc: 41.0%(valid) | 	RMSE: 106.3(valid)
# Epoch: 18
# 	Loss: 0.4427(train)
# 	Loss: 1.9808(valid)	|	Acc: 41.1%(valid) | 	RMSE: 105.7(valid)
# Epoch: 19
# 	Loss: 0.4140(train)
# 	Loss: 1.9895(valid)	|	Acc: 41.2%(valid) | 	RMSE: 107.1(valid)
# Epoch: 20
# 	Loss: 0.3786(train)
# 	Loss: 2.0719(valid)	|	Acc: 41.2%(valid) | 	RMSE: 107.2(valid)
# Epoch: 21
# 	Loss: 0.3545(train)
# 	Loss: 2.2094(valid)	|	Acc: 41.4%(valid) | 	RMSE: 106.5(valid)
# Epoch: 22
# 	Loss: 0.3389(train)
# 	Loss: 2.2503(valid)	|	Acc: 42.0%(valid) | 	RMSE: 107.8(valid)
# Epoch: 23
# 	Loss: 0.3174(train)
# 	Loss: 2.2958(valid)	|	Acc: 41.8%(valid) | 	RMSE: 107.1(valid)
# Epoch: 24
# 	Loss: 0.3045(train)
# 	Loss: 2.2364(valid)	|	Acc: 41.0%(valid) | 	RMSE: 107.7(valid)
# Epoch: 25
# 	Loss: 0.2882(train)
# 	Loss: 2.3437(valid)	|	Acc: 42.4%(valid) | 	RMSE: 108.5(valid)
# Epoch: 26
# 	Loss: 0.2685(train)
# 	Loss: 2.4103(valid)	|	Acc: 42.0%(valid) | 	RMSE: 109.8(valid)
# Epoch: 27
# 	Loss: 0.2632(train)
# 	Loss: 2.3365(valid)	|	Acc: 41.9%(valid) | 	RMSE: 110.0(valid)
# Epoch: 28
# 	Loss: 0.2499(train)
# 	Loss: 2.4715(valid)	|	Acc: 42.2%(valid) | 	RMSE: 111.6(valid)
# Epoch: 29
# 	Loss: 0.2345(train)
# 	Loss: 2.5189(valid)	|	Acc: 42.3%(valid) | 	RMSE: 109.4(valid)
# Epoch: 30
# 	Loss: 0.2297(train)
# 	Loss: 2.5829(valid)	|	Acc: 42.2%(valid) | 	RMSE: 112.0(valid)
# Epoch: 31
# 	Loss: 0.2131(train)
# 	Loss: 2.6059(valid)	|	Acc: 41.8%(valid) | 	RMSE: 110.3(valid)
# Epoch: 32
# 	Loss: 0.2029(train)
# 	Loss: 2.6468(valid)	|	Acc: 42.3%(valid) | 	RMSE: 112.9(valid)
# Epoch: 33
# 	Loss: 0.1966(train)
# 	Loss: 2.6014(valid)	|	Acc: 41.8%(valid) | 	RMSE: 110.9(valid)
# Epoch: 34
# 	Loss: 0.1808(train)
# 	Loss: 2.7081(valid)	|	Acc: 42.1%(valid) | 	RMSE: 109.9(valid)
# Epoch: 35
# 	Loss: 0.1769(train)
# 	Loss: 2.7556(valid)	|	Acc: 41.5%(valid) | 	RMSE: 111.8(valid)
# Epoch: 36
# 	Loss: 0.1710(train)
# 	Loss: 2.7429(valid)	|	Acc: 41.9%(valid) | 	RMSE: 109.8(valid)
# Epoch: 37
# 	Loss: 0.1578(train)
# 	Loss: 2.7921(valid)	|	Acc: 42.2%(valid) | 	RMSE: 111.6(valid)
# Epoch: 38
# 	Loss: 0.1584(train)
# 	Loss: 2.8107(valid)	|	Acc: 42.0%(valid) | 	RMSE: 113.5(valid)
# Epoch: 39
# 	Loss: 0.1544(train)
# 	Loss: 2.9539(valid)	|	Acc: 42.4%(valid) | 	RMSE: 112.9(valid)
# Epoch: 40
# 	Loss: 0.1491(train)
# 	Loss: 2.7984(valid)	|	Acc: 42.5%(valid) | 	RMSE: 114.7(valid)
# Epoch: 41
# 	Loss: 0.1407(train)
# 	Loss: 2.9351(valid)	|	Acc: 43.2%(valid) | 	RMSE: 110.2(valid)
# Epoch: 42
# 	Loss: 0.1360(train)
# 	Loss: 2.9076(valid)	|	Acc: 42.3%(valid) | 	RMSE: 113.7(valid)
# Epoch: 43
# 	Loss: 0.1339(train)
# 	Loss: 2.9618(valid)	|	Acc: 42.3%(valid) | 	RMSE: 111.7(valid)
# Epoch: 44
# 	Loss: 0.1317(train)
# 	Loss: 2.8564(valid)	|	Acc: 42.3%(valid) | 	RMSE: 110.8(valid)
# Epoch: 45
# 	Loss: 0.1288(train)
# 	Loss: 2.9197(valid)	|	Acc: 41.8%(valid) | 	RMSE: 112.1(valid)
# Epoch: 46
# 	Loss: 0.1249(train)
# 	Loss: 3.0334(valid)	|	Acc: 42.0%(valid) | 	RMSE: 110.9(valid)
# Epoch: 47
# 	Loss: 0.1186(train)
# 	Loss: 3.0479(valid)	|	Acc: 42.2%(valid) | 	RMSE: 110.1(valid)
# Epoch: 48
# 	Loss: 0.1168(train)
# 	Loss: 2.9796(valid)	|	Acc: 42.4%(valid) | 	RMSE: 112.9(valid)
# Epoch: 49
# 	Loss: 0.1131(train)
# 	Loss: 2.9617(valid)	|	Acc: 42.4%(valid) | 	RMSE: 111.9(valid)
# Epoch: 50
# 	Loss: 0.1154(train)
# 	Loss: 3.0068(valid)	|	Acc: 43.0%(valid) | 	RMSE: 110.0(valid)
# Normalized confusion matrix
# [[0.55 0.27 0.12 0.06]
#  [0.19 0.4  0.29 0.12]
#  [0.09 0.34 0.38 0.19]
#  [0.06 0.21 0.34 0.39]]

# %%
pred = [0,2,1,0,2,1]
labels = [0,1,1,2,1,1]

conf_matrix = confusion_matrix(np.array(labels), np.array(pred), labels=[0, 1, 2])
np.set_printoptions(precision=2)
# Plot non-normalized confusion matrix
#plt.figure()
#plot_confusion_matrix(conf_matrix, classes=['10s', '20s', '30s'], title='Confusion matrix')
